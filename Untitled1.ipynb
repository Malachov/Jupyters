# %% [markdown]
# sadfsadf

# %% [markdown]
# imggin
#
#
# <div>
# <img src="img/Gini.png" width="500"/>
# </div>

# %% [markdown]
# attach
#
# <div>
# <img src="attachment:Gini.png" width="500"/>
# </div>
